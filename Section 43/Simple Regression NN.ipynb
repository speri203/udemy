# %% [markdown]
# # Simple Linear Regression. Minimal example

# %% [markdown]
# ### Import the relevant libraries

# %%
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
sb.set()

# %% [markdown]
# ### Generate random input data to train on

# %%
observations = 1000

## The size is number of observations by the number of variables we have. This is
## an example of a basic linear model
xs = np.random.uniform(low=-10, high=10, size=(observations,1))
zs = np.random.uniform(-10,10, (observations,1))

inputs = np.column_stack((xs,zs))
inputs
# Out:
# array([[ 6.95552989, -4.57299631],
#        [ 2.92191075, -6.35404553],
#        [ 5.93848607,  0.94585824],
#        ...,
#        [-8.44421523, -6.58644852],
#        [-2.03680752,  5.76531728],
#        [-4.02584102,  8.08681954]])

# %% [markdown]
# ### Create targets we will aim at

# %%
noise = np.random.uniform(-1, 1, (observations,1))

targets = 2*xs - 3*zs + 5 + noise
targets.shape
# Out:
# (1000, 1)

# %% [markdown]
# ### Plot the training data

# %%
#

# %% [markdown]
# ### Initialize Variables

# %%
init_range = 0.1
weights = np.random.uniform(-init_range, init_range, size=(2,1))
bias = np.random.uniform(-init_range, init_range, size=(1,1))

print(weights)
print(bias)
# Out:
# [[-0.07073194]
#  [-0.00223167]]
# [[-0.09849565]]

# %% [markdown]
# ### Specify learning rate

# %%
learning_rate = 0.02

# %% [markdown]
# ### Train the Model

# %%
for i in range(100):
    outputs = np.dot(inputs, weights) + bias
    deltas = outputs - targets

    loss = np.sum(deltas ** 2) / 2 / observations
    print("Loss: " + str(loss))

    deltas_scaled = deltas / observations

    weights = weights - learning_rate * np.dot(inputs.T,deltas_scaled)
    bias = bias - learning_rate * np.sum(deltas_scaled)
# Out:
# Loss: 0.1664976108861317
# Loss: 0.1663368639942306
# Loss: 0.16618248146020023
# Loss: 0.16603421130373375
# Loss: 0.1658918115210342
# Loss: 0.16575504968981886
# Loss: 0.16562370258996548
# Loss: 0.16549755583917544
# Loss: 0.16537640354306357
# Loss: 0.16526004795910068
# Loss: 0.16514829917386248
# Loss: 0.1650409747930558
# Loss: 0.16493789964381803
# Loss: 0.16483890548880403
# Loss: 0.1647438307515913
# Loss: 0.16465252025295832
# Loss: 0.16456482495760413
# Loss: 0.16448060173089527
# Loss: 0.16439971310524437
# Loss: 0.16432202705573803
# Loss: 0.1642474167846482
# Loss: 0.16417576051447486
# Loss: 0.1641069412891843
# Loss: 0.16404084678331413
# Loss: 0.16397736911863858
# Loss: 0.16391640468809165
# Loss: 0.16385785398666133
# Loss: 0.16380162144897947
# Loss: 0.16374761529334164
